# %% [markdown]
# ## **Aim of this notebook is to download SDF files of all the 212 molecules from drug bank for virtual screening**

# %%
import pandas as pd

# %%
act_df = pd.read_csv("active_molecules_1.csv")

# %%
act_df
# Out:
#      KNN  SVM  XGBoost DrugBank ID  \
# 0      0    1        1     DB00125
# 1      0    1        1     DB00278
# 2      1    1        0     DB00310
# 3      0    1        1     DB00311
# 4      0    1        1     DB00398
# ..   ...  ...      ...         ...
# 207    0    1        1     DB18060
# 208    0    1        1     DB18068
# 209    1    1        0     DB18151
# 210    0    1        1     DB18345
# 211    1    0        0     DB18523
#
#                                                 SMILES
# 0                            N[C@@H](CCCNC(N)=N)C(O)=O
# 1    C[C@@H]1CCN([C@H](C1)C(O)=O)C(=O)[C@H](CCCNC(N...
# 2    NS(=O)(=O)C1=C(Cl)C=CC(=C1)C1(O)NC(=O)C2=CC=CC...
# 3                   CCOC1=CC2=C(C=C1)N=C(S2)S(N)(=O)=O
# 4    CNC(=O)C1=NC=CC(OC2=CC=C(NC(=O)NC3=CC(=C(Cl)C=...
# ..                                                 ...
# 207  CC1=CC(=CC=N1)C1=NC(=CO1)C(=O)NC1=C(N=C2N=C(OC...
# 208      ONC(=O)C1=NOC(CCNC(=O)C2=CC=C(Cl)C(Cl)=C2)=C1
# 209  NC(CO)(CO)CCC1=CC=C(SC2=CC=CC(OCC3=CC=CC=C3)=C...
# 210  CC(C)[C@H](NC(C)=O)C(=O)N[C@@H](CO)C(=O)N[C@@H...
# 211  O=[186Re+3].CCN(CC)CCN(CCS)CC[S-].CCN(CC)CCN(C...
#
# [212 rows x 5 columns]

# %%
ids = act_df['DrugBank ID'].to_list()

# %%
ids
# Out:
# ['DB00125',
#  'DB00278',
#  'DB00310',
#  'DB00311',
#  'DB00398',
#  'DB00547',
#  'DB00623',
#  'DB00686',
#  'DB00744',
#  'DB00772',
#  'DB00875',
#  'DB00878',
#  'DB00975',
#  'DB01247',
#  'DB01249',
#  'DB01624',
#  'DB01683',
#  'DB01687',
#  'DB01741',
#  'DB01992',
#  'DB02046',
#  'DB02061',
#  'DB02090',
#  'DB02215',
#  'DB02269',
#  'DB02295',
#  'DB02433',
#  'DB02812',
#  'DB02942',
#  'DB03082',
#  'DB03136',
#  'DB03152',
#  'DB03161',
#  'DB03232',
#  'DB03235',
#  'DB03250',
#  'DB03291',
#  'DB03323',
#  'DB03524',
#  'DB03542',
#  'DB03642',
#  'DB03840',
#  'DB03974',
#  'DB04008',
#  'DB04027',
#  'DB04071',
#  'DB04073',
#  'DB04096',
#  'DB04189',
#  'DB04350',
#  'DB04360',
#  'DB04433',
#  'DB04446',
#  'DB04452',
#  'DB04465',
#  'DB04526',
#  'DB04571',
#  'DB04591',
#  'DB04595',
#  'DB04661',
#  'DB04710',
#  'DB04759',
#  'DB04760',
#  'DB04761',
#  'DB04791',
#  'DB04793',
#  'DB04838',
#  'DB04855',
#  'DB05102',
#  'DB05155',
#  'DB05380',
#  'DB06090',
#  'DB06124',
#  'DB06367',
#  'DB06598',
#  'DB06684',
#  'DB06726',
#  'DB06900',
#  'DB07020',
#  'DB07063',
#  'DB07093',
#  'DB07146',
#  'DB07147',
#  'DB07167',
#  'DB07270',
#  'DB07278',
#  'DB07312',
#  'DB07321',
#  'DB07430',
#  'DB07512',
#  'DB07544',
#  'DB07580',
#  'DB07843',
#  'DB07844',
#  'DB07853',
#  'DB07879',
#  'DB07916',
#  'DB07974',
#  'DB08021',
#  'DB08022',
#  'DB08046',
#  'DB08143',
#  'DB08310',
#  'DB08326',
#  'DB08410',
#  'DB08487',
#  'DB08495',
#  'DB08624',
#  'DB08733',
#  'DB08757',
#  'DB08765',
#  'DB08772',
#  'DB08896',
#  'DB09013',
#  'DB09075',
#  'DB09134',
#  'DB09184',
#  'DB11448',
#  'DB11460',
#  'DB11472',
#  'DB11497',
#  'DB11648',
#  'DB11698',
#  'DB11726',
#  'DB11792',
#  'DB11815',
#  'DB11879',
#  'DB11890',
#  'DB11891',
#  'DB11969',
#  'DB11981',
#  'DB12015',
#  'DB12042',
#  'DB12079',
#  'DB12120',
#  'DB12138',
#  'DB12148',
#  'DB12178',
#  'DB12232',
#  'DB12285',
#  'DB12288',
#  'DB12326',
#  'DB12391',
#  'DB12439',
#  'DB12441',
#  'DB12492',
#  'DB12513',
#  'DB12547',
#  'DB12565',
#  'DB12598',
#  'DB12669',
#  'DB12692',
#  'DB12710',
#  'DB12831',
#  'DB12991',
#  'DB13005',
#  'DB13060',
#  'DB13207',
#  'DB13239',
#  'DB13290',
#  'DB13291',
#  'DB13659',
#  'DB13748',
#  'DB13841',
#  'DB13876',
#  'DB13944',
#  'DB14070',
#  'DB14111',
#  'DB14706',
#  'DB14911',
#  'DB14936',
#  'DB14943',
#  'DB15051',
#  'DB15079',
#  'DB15121',
#  'DB15199',
#  'DB15251',
#  'DB15265',
#  'DB15307',
#  'DB15381',
#  'DB15382',
#  'DB15391',
#  'DB15393',
#  'DB15414',
#  'DB15419',
#  'DB15955',
#  'DB16025',
#  'DB16122',
#  'DB16339',
#  'DB16707',
#  'DB16758',
#  'DB16838',
#  'DB16851',
#  'DB16872',
#  'DB16878',
#  'DB16889',
#  'DB16954',
#  'DB16961',
#  'DB17029',
#  'DB17038',
#  'DB17071',
#  'DB17269',
#  'DB17549',
#  'DB17560',
#  'DB17692',
#  'DB18036',
#  'DB18037',
#  'DB18060',
#  'DB18068',
#  'DB18151',
#  'DB18345',
#  'DB18523']

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import requests
import os

# List of DrugBank IDs
drugbank_ids = ids

# Function to download SDF file for a DrugBank ID
def download_sdf(drugbank_id):
    url = f'https://go.drugbank.com/structures/small_molecule_drugs/{drugbank_id}.sdf'
    # url = f'https://go.drugbank.com/structures/{drugbank_id}/download_sdf'
    response = requests.get(url)
    if response.status_code == 200:
        if not os.path.exists('SDFs'):
            os.makedirs('SDFs')
        with open(f'SDFs/{drugbank_id}.sdf', 'wb') as file:
            file.write(response.content)
            print(f'{drugbank_id} SDF file downloaded successfully')
    else:
        print(f'Failed to download SDF file for {drugbank_id}')

# Download SDF files for each DrugBank ID
for drugbank_id in drugbank_ids:
    download_sdf(drugbank_id)
# Out:
# DB00125 SDF file downloaded successfully
# DB00278 SDF file downloaded successfully
# DB00310 SDF file downloaded successfully
# DB00311 SDF file downloaded successfully
# DB00398 SDF file downloaded successfully
# DB00547 SDF file downloaded successfully
# DB00623 SDF file downloaded successfully
# DB00686 SDF file downloaded successfully
# DB00744 SDF file downloaded successfully
# DB00772 SDF file downloaded successfully
# DB00875 SDF file downloaded successfully
# DB00878 SDF file downloaded successfully
# DB00975 SDF file downloaded successfully
# DB01247 SDF file downloaded successfully
# DB01249 SDF file downloaded successfully
# DB01624 SDF file downloaded successfully
# DB01683 SDF file downloaded successfully
# DB01687 SDF file downloaded successfully
# DB01741 SDF file downloaded successfully
# DB01992 SDF file downloaded successfully
# DB02046 SDF file downloaded successfully
# DB02061 SDF file downloaded successfully
# DB02090 SDF file downloaded successfully
# DB02215 SDF file downloaded successfully
# DB02269 SDF file downloaded successfully
# DB02295 SDF file downloaded successfully
# DB02433 SDF file downloaded successfully
# DB02812 SDF file downloaded successfully
# DB02942 SDF file downloaded successfully
# DB03082 SDF file downloaded successfully
# DB03136 SDF file downloaded successfully
# DB03152 SDF file downloaded successfully
# DB03161 SDF file downloaded successfully
# DB03232 SDF file downloaded successfully
# DB03235 SDF file downloaded successfully
# DB03250 SDF file downloaded successfully
# DB03291 SDF file downloaded successfully
# DB03323 SDF file downloaded successfully
# DB03524 SDF file downloaded successfully
# DB03542 SDF file downloaded successfully
# DB03642 SDF file downloaded successfully
# DB03840 SDF file downloaded successfully
# DB03974 SDF file downloaded successfully
# DB04008 SDF file downloaded successfully
# DB04027 SDF file downloaded successfully
# DB04071 SDF file downloaded successfully
# DB04073 SDF file downloaded successfully
# DB04096 SDF file downloaded successfully
# DB04189 SDF file downloaded successfully
# DB04350 SDF file downloaded successfully
# DB04360 SDF file downloaded successfully
# DB04433 SDF file downloaded successfully
# DB04446 SDF file downloaded successfully
# DB04452 SDF file downloaded successfully
# DB04465 SDF file downloaded successfully
# DB04526 SDF file downloaded successfully
# DB04571 SDF file downloaded successfully
# DB04591 SDF file downloaded successfully
