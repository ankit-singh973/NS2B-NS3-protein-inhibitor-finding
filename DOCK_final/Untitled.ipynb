# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A29E-1842
#
#  Directory of C:\Users\Ankit\Desktop\DOCK_final
#
# 15-05-2024  06:31    <DIR>          .
# 15-05-2024  00:29    <DIR>          ..
# 15-05-2024  06:31    <DIR>          .ipynb_checkpoints
# 10-05-2024  22:16             5,888 17692_1.pdb
# 10-05-2024  22:16             5,888 17692_2.pdb
# 08-05-2024  16:34           239,525 A&B _chain.pdb
# 09-05-2024  14:02           296,271 db17692.pdb
# 08-05-2024  23:26    <DIR>          glide-grid_1
# 08-05-2024  22:28    <DIR>          ligprep_1
# 04-05-2024  01:51         1,028,722 merged.sdf
# 08-05-2024  21:31           143,539 Output_final.pdb
# 08-05-2024  22:02    <DIR>          proteinprep_1
# 09-05-2024  10:59           976,620 pymol.png
# 09-05-2024  10:52           108,366 result.csv
# 09-05-2024  11:00           233,918 structure.png
# 10-05-2024  22:48            35,407 structure_2.png
# 09-05-2024  10:48            33,149 Top structure.png
# ...

# %%
df = pd.read_csv("result.csv")

# %%
df
# Out:
#     Stars                                    Title  Entry ID  \
# 0     NaN                  Output_final - prepared         1
# 1     NaN                  Output_final - prepared         2
# 2     NaN                          ligprep_1.sdf:8         3
# 3     NaN  Output_final - prepared ligprep_1.sdf:8        58
# 4     NaN                          ligprep_1.sdf:8         4
# 5     NaN                                      382         5
# 6     NaN                                      NSC         6
# 7     NaN                          ligprep_1.sdf:7         7
# 8     NaN                          ligprep_1.sdf:7         8
# 9     NaN                         ligprep_1.sdf:99         9
# 10    NaN                          ligprep_1.sdf:7        10
# 11    NaN                         ligprep_1.sdf:59        11
# 12    NaN                          ligprep_1.sdf:7        12
# 13    NaN                                      382        13
# ...

# %%
df.columns
# Out:
# Index(['Stars', 'Title', 'Entry ID', 'Entry Name', 'Date Added',
#        'Date Modified', 'PDB format version', 'PDB EXPDTA', 'Source Path',
#        'Source File',
#        ...
#        'JCHEM_PKA_STRONGEST_ACIDIC', 'JCHEM_PKA_STRONGEST_BASIC',
#        'ALOGPS_SOLUBILITY', 'tautomer probability', 'JCHEM_PKA',
#        'SECONDARY_ACCESSION_NUMBERS', 'Chemistry Notes',
#        'INTERNATIONAL_BRANDS', 'PRODUCTS', 'Mark'],
#       dtype='object', length=176)

# %%
selection = ['Title', 'Entry ID', 'DATABASE_ID','SMILES', 'DRUG_GROUPS', 'GENERIC_NAME', 'docking score']
df2 = df[selection]

# %%
df2.columns
# Out:
# Index(['Title', 'Entry ID', 'DATABASE_ID', 'SMILES', 'DRUG_GROUPS',
#        'GENERIC_NAME', 'docking score'],
#       dtype='object')

# %%
df2.to_csv("vs_final_results.csv", index = False)
